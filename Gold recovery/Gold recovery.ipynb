# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-рассчета-эффективность-обогащения" data-toc-modified-id="Проверка-рассчета-эффективность-обогащения-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Проверка рассчета эффективность обогащения</a></span></li><li><span><a href="#Признаки,-недоступные-в-тестовой-выборке" data-toc-modified-id="Признаки,-недоступные-в-тестовой-выборке-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Признаки, недоступные в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределение-концентрации-металлов-(Au,-Ag,-Pb)--на-различных-ступенях-обработки" data-toc-modified-id="Распределение-концентрации-металлов-(Au,-Ag,-Pb)--на-различных-ступенях-обработки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Распределение концентрации металлов (Au, Ag, Pb)  на различных ступенях обработки</a></span></li><li><span><a href="#Распределения-размеров-гранул-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Распределения-размеров-гранул-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределения размеров гранул на обучающей и тестовой выборках</a></span></li><li><span><a href="#Распределение-суммарных-концентраций" data-toc-modified-id="Распределение-суммарных-концентраций-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Распределение суммарных концентраций</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Модель-LinearRegression" data-toc-modified-id="Модель-LinearRegression-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Модель LinearRegression</a></span></li><li><span><a href="#Модель-DecisionTreeRegressor" data-toc-modified-id="Модель-DecisionTreeRegressor-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Модель DecisionTreeRegressor</a></span></li><li><span><a href="#Модель-RandomForestRegressor" data-toc-modified-id="Модель-RandomForestRegressor-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Модель RandomForestRegressor</a></span></li><li><span><a href="#Подготовим-данные-для-тестирования-и-применим-модель-на-тестовой-выборке" data-toc-modified-id="Подготовим-данные-для-тестирования-и-применим-модель-на-тестовой-выборке-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Подготовим данные для тестирования и применим модель на тестовой выборке</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li></ul></li></ul></li><li><span><a href="#Вывод-по-проекту" data-toc-modified-id="Вывод-по-проекту-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><strong>Вывод по проекту</strong></a></span></li></ul></div>

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# # Технологический процесс

# %% [markdown]
# Стадии восстановления:
#
# **1. Флотация**
#
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# **2. Очистка**
#
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# **Описание данных**

# %% [markdown]
# - Rougher feed — исходное сырье
#
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#
#     - Xanthate — ксантогенат (промотер, или активатор флотации);
#     - Sulphate — сульфат (на данном производстве сульфид натрия);
#     - Depressant — депрессант (силикат натрия).
#
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# Параметры этапов
#
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи

# %% [markdown]
# ## Подготовка данных

# %%
#импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor

from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.metrics import mean_absolute_error, make_scorer

from numpy.random import RandomState

import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# %%
#загрузка данных
df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %% [markdown]
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# В данных есть пропуски, столбец date имеет тип object, заменим на datetime, в остальном типы данных соответствует задаче.

# %%
df_train['date'] = pd.to_datetime(df_train['date'], format='%Y-%m-%d %H:%M:%S')
df_test['date'] = pd.to_datetime(df_test['date'], format='%Y-%m-%d %H:%M:%S')
df_full['date'] = pd.to_datetime(df_full['date'], format='%Y-%m-%d %H:%M:%S')

# %%
df_train.head()
# Out:
#                  date  final.output.concentrate_ag  \
# 0 2016-01-15 00:00:00                     6.055403
# 1 2016-01-15 01:00:00                     6.029369
# 2 2016-01-15 02:00:00                     6.055926
# 3 2016-01-15 03:00:00                     6.047977
# 4 2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
df_test.head()
# Out:
#                  date  primary_cleaner.input.sulfate  \
# 0 2016-09-01 00:59:59                     210.800909
# 1 2016-09-01 01:59:59                     215.392455
# 2 2016-09-01 02:59:59                     215.259946
# 3 2016-09-01 03:59:59                     215.336236
# 4 2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
# ...

# %%
df_full.head()
# Out:
#                  date  final.output.concentrate_ag  \
# 0 2016-01-15 00:00:00                     6.055403
# 1 2016-01-15 01:00:00                     6.029369
# 2 2016-01-15 02:00:00                     6.055926
# 3 2016-01-15 03:00:00                     6.047977
# 4 2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# ### Проверка рассчета эффективность обогащения

# %% [markdown]
# $$ Recovery = \frac{C*(F-T)}{F*(C-T)}*100\%$$

# %% [markdown]
# где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.

# %%
C = df_train['rougher.output.concentrate_au']
F = df_train['rougher.input.feed_au']
T = df_train['rougher.output.tail_au']
recovery_rougher = (C * (F-T)) / (F * (C - T)) * 100

# %% [markdown]
# Найдём среднюю абсолютную ошибку между расчётами и значением признака.

# %%
mean_absolute_error(recovery_rougher, df_train['rougher.output.recovery'])
# Out:
# 9.73512347450521e-15

# %%
_C = df_train['final.output.concentrate_au']
_T = df_train['final.output.tail_au']
recovery_final = (_C * (F-_T)) / (F * (_C - _T)) * 100

# %%
mean_absolute_error(recovery_final, df_train['final.output.recovery'])
# Out:
# 8.538049763979541e-15

# %% [markdown]
# Ошибка стремится к нулю, расчеты можно считать верными.

# %% [markdown]
# ### Признаки, недоступные в тестовой выборке

# %%
sorted(set(df_full.columns) - set(df_test.columns))
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Отсутствующие признаки это выходные признаки после каждого технологического этапа. Также недоступны целевые признаки final.output.recovery и rougher.output.recovery. В дальнейшем они понадобятся для подсчета метрики sMAPE. Отсутствие признаков можно обьяснить тем, что на их основе можно вычислить целевые признаки и их присутствие может привести к утечки информации.

# %% [markdown]
# Добавим целевые признаки в тестовую выборку, в качестве индексов используем колонку date.

# %%
df_test = df_test.merge(df_full.loc[:, ['date','rougher.output.recovery','final.output.recovery']], on='date')

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Проверка явных дубликатов

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В датасетах имеются пропуски, кол-во их менее 10 процентов от них можно избавиться, но известно, что данные индексируются датой и временем получения информации и соседние по времени значения часто похожи. Можно воспользоваться данным условием и с помощью функции ffill заполнить отсутствующие значения.

# %%
#общее кол-во пропусков
df_full.isna().sum().sum()
# Out:
# 4481

# %%
#кол-во пропусков в тренировочном датасете
df_train.isna().sum().sum()
# Out:
# 4100

# %%
#кол-во пропусков в тестовом датасете
df_test.isna().sum().sum()
# Out:
# 90

# %%
df_full = df_full.ffill(axis=0)
df_train = df_train.ffill(axis=0)
df_test = df_test.ffill(axis=0)

# %%
#общее кол-во пропусков
df_full.isna().sum().sum()
# Out:
# 0

# %%
#кол-во пропусков в тренировочном датасете
df_train.isna().sum().sum()
# Out:
# 0

# %%
#кол-во пропусков в тестовом датасете
df_test.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# **Вывод**
#
# - Был изменен тип данных для столбца date с object на datetime.
#
# - Пропуски в тренировочном и тестовом датасетах были заполнены значениями предшествующими по времени.
#
# - Проверена правильность расчета эффективности обогащения.
#
# - В тестовом датасете отсутствовало 34 значения.
#
# - В тестовую выборку добавлены целевые признаки `rougher.output.recovery` и `final.output.recovery`, которые будут необходимы в дальнейшем для рассчета итоговой метрики качества.
# - Дубликаты в датасэтах не найдены не найдены, пропуски в знчениях заполнены функцией ffill.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Распределение концентрации металлов (Au, Ag, Pb)  на различных ступенях обработки

# %%
sns.set(style="whitegrid")

# %%
#Функция построения графиков концентрации каждого металла на различных этапах очистки
def metal_hist(metal, title):
    x0 = df_full[f'rougher.input.feed_{metal}']
    x1 = df_full[f'rougher.output.concentrate_{metal}']
    x2 = df_full[f'primary_cleaner.output.concentrate_{metal}']
    x3 = df_full[f'final.output.concentrate_{metal}']

    plt.figure(figsize=(15, 10))

    sns.distplot(x0, kde_kws= {"label": "Сырье"})
    sns.distplot(x1, kde_kws= {"label": "Черновой концентрат"})
    sns.distplot(x2, kde_kws= {"label": "Первичная очистка"})
    sns.distplot(x3, kde_kws= {"label": "Финальный этап"})
    
    plt.title(label=f'Концентрация {title} на различных этапах очистки', fontsize=15)
    plt.xlabel('Концентрация')
    plt.ylabel('Количество наблюдений')
    plt.legend()

# %%
#Функция построения графиков концентрации всех металлов на различных этапах очистки
def metal_step_hist(data, title):
    
    plt.figure(figsize=(15, 10))  

    for i in ['au', 'ag', 'pb']:
        sns.distplot(df_full[f'{data}_{i}'], kde_kws= {"label": f'Концентрация {i}'})
  
    plt.title(label=f'Концентрация металлов, этап - {title}', fontsize=15)
    plt.xlabel('Концентрация')
    plt.ylabel('Количество наблюдений')
    plt.legend()

# %%
metal_hist('au', 'золота')

# %%
metal_hist('ag', 'серебра')

# %%
metal_hist('pb', 'свинца')

# %%
metal_step_hist('rougher.input.feed', 'Сырье')

# %%
metal_step_hist('rougher.output.concentrate', 'Черновой концентрат')

# %%
metal_step_hist('primary_cleaner.output.concentrate', 'Первичная очистка')

# %%
metal_step_hist('final.output.concentrate', 'Финальный этап')

# %% [markdown]
# **Вывод**
#
# - Доля золота на после каждого этапа очитски увеличивается.
# - Доля серебра увеличивается на этапе флотации, а затем постепенно снижается.
# - Доля свинца  увеличивается на этапе флотации и после первичной очитски, но затем остатется примерно на одном уровне.
# - В данных для каждого металла присутствуют аномалии.

# %% [markdown]
# ### Распределения размеров гранул на обучающей и тестовой выборках

# %%
plt.figure(figsize=(15,8))
sns.distplot(df_train['rougher.input.feed_size'], label='обучающая выборка')
sns.distplot(df_test['rougher.input.feed_size'], label='тестовая выборка')
plt.title('Размер гранул на этапе флотации для обучающей и тестовой выборкок', fontsize=15)
plt.legend()
plt.xlabel('Размер гранул')
plt.ylabel('Количество наблюдений')
plt.xlim(20, 110)
# Out:
# (20.0, 110.0)

# %%
plt.figure(figsize=(15,8))
sns.distplot(df_train['primary_cleaner.input.feed_size'], label='обучающая выборка')
sns.distplot(df_test['primary_cleaner.input.feed_size'], label='тестовая выборка')
plt.title('Размер гранул на этапе первичной очистки для обучающей и тестовой выборкок', fontsize=15)
plt.legend()
plt.xlabel('Размер гранул')
plt.ylabel('Количество наблюдений')
plt.xlim(4, 12)
# Out:
# (4.0, 12.0)

# %% [markdown]
# - Для этапа флотации распределение гранул находится примерно в одинаковом диапазоне, но для тренировочной выборки преобладают гранулы с размером 50-60, а для тестовой 40-50.
#
# - Для этапа первичной очитски распределение гранул находится в одном диапазоне.
#
# Таким образом, значимых различий между распределениями для выборок не наблюдается.

# %% [markdown]
# ### Распределение суммарных концентраций

# %%
# Суммирование концентраций по этапам
rougher_input =0
final = 0
rougher_output = 0
primary_cleaner_output = 0
for i in ['ag', 'au', 'pb', 'sol']:
    rougher_input += df_full[f'rougher.input.feed_{i}']
    final += df_full[f'final.output.concentrate_{i}']
    rougher_output += df_full[f'rougher.output.concentrate_{i}']
    primary_cleaner_output += df_full[f'primary_cleaner.output.concentrate_{i}']

# %%
plt.figure(figsize=[15, 9])
plt.suptitle('Распределение суммарных концентраций', fontsize=15)
sns.distplot(rougher_input, color='g', label='Сырье', kde=False)
sns.distplot(rougher_output, color='b', label='Концентрация после флотации', kde=False)
sns.distplot(primary_cleaner_output, color='y', label='Концентрация после первичной очистки', kde=False)
sns.distplot(final, color='r', label='Финальная концетрация',kde=False)
plt.xlabel('Концентрация веществ')
plt.ylabel('Количество наблюдений')
plt.legend()
plt.show();

# %% [markdown]
# **Вывод**
# - По распределениям видно, что в данных присутствуют выбросы и длинные левые хвосты из-за золота.
# - Суммарная концентрация веществ увеличивается к финальному этапу, а диапазон распределения уменьшается.

# %% [markdown]
# В целевых признаках во всех выборках присутствуют значения равные нулю.

# %%
plt.plot()
df_train['final.output.recovery'].plot(title = 'final.output.recovery')
plt.xlim(4000, 5000);

# %%
print('Количество значений менее 5% в тренировочной выборке',
      df_train[df_train['rougher.output.recovery'] < 5]['rougher.output.recovery'].count() +
      df_train[df_train['final.output.recovery'] < 5]['final.output.recovery'].count())
print('Количество значений менее 5% в тестовой выборке', 
      df_test[df_test['rougher.output.recovery'] < 5]['rougher.output.recovery'].count() + 
      df_test[df_test['final.output.recovery'] < 5]['final.output.recovery'].count())
# Out:
# Количество значений менее 5% в тренировочной выборке 361
# Количество значений менее 5% в тестовой выборке 139

# %% [markdown]
# Далее для более качественной модели значения менее 5% заменяются на средние значения.

# %%
df_train.loc[df_train['rougher.output.recovery'] < 5] = df_full['rougher.output.recovery'].mean()
df_train.loc[df_train['final.output.recovery'] < 5] = df_full['final.output.recovery'].mean()

# %%
plt.plot()
df_train['final.output.recovery'].plot(title = 'final.output.recovery')
plt.xlim(4000, 5000);

# %% [markdown]
# Так как остальные выбросы присутствуют в признаках, отсутствующих в тестовой выборке, то с ними можно ничего не делать.
# Перед началом обучения моделей необходимо избавиться от признаков, которые отсутствуют в тестовой выборке, а также от столбца `date`. Единственные признаки, в которых есть выбросы и они присутствуют в тестовой выборке являются признаки `rougher.input.feed_`.

# %%
for i in ['au', 'ag', 'pb']:
    df_train = df_train[df_train[f'rougher.input.feed_{i}'] > 1]

# %%
train = df_train[df_test.columns]
test = df_test

test.drop(['date'], axis=1, inplace=True)
train.drop(['date'], axis=1, inplace=True)

# %%
train.shape
# Out:
# (14004, 54)

# %% [markdown]
# ## Модель

# %%
#sMAPE 
def sMAPE(target, predict):
    smape = (1 / len(target)) * np.sum((np.abs(target - predict)) / ((np.abs(target) + np.abs(predict)) / 2)) *100
    return smape

# %%
#Окончательное sMAPE 
def final_sMAPE(rougher, final):
    final_smape = 0.25 * rougher + 0.75 * final
    return final_smape

# %%
smape_score = make_scorer(sMAPE, greater_is_better = False)

# %%
state = 42

# %% [markdown]
# Подготовим данные для обучения моделей

# %%
features_for_train = train.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_for_rougher_train = train['rougher.output.recovery']
target_for_final_train = train['final.output.recovery']

# %%
scores = {}

# %% [markdown]
# ### Модель LinearRegression

# %%
# %%time
model_lr_rougher = LinearRegression()
smape_rougher = cross_val_score(model_lr_rougher,
                          features_for_train,
                          target_for_rougher_train,
                          scoring=smape_score,
                          cv=5)

model_lr_final = LinearRegression()
smape_final = cross_val_score(model_lr_final,
                        features_for_train,
                        target_for_final_train,
                        scoring=smape_score,
                        cv=5)

result_smape = final_sMAPE(smape_rougher.mean(), smape_final.mean())*(-1)

scores['LinearRegression'] = [result_smape]
# Out:
# CPU times: user 1.38 s, sys: 1.53 s, total: 2.91 s
# Wall time: 2.87 s

# %% [markdown]
# ### Модель DecisionTreeRegressor

# %%
# %%time
#GridSearchCV for rougher
params_dtr_grid = {
    'max_depth' : range(1, 15)
}

grid_model_dt_rougher = GridSearchCV(DecisionTreeRegressor(random_state=state), 
                                     param_grid = params_dtr_grid,
                                     cv=KFold(5, shuffle=True, random_state=state),
                                     n_jobs=-1, 
                                     scoring=smape_score) 

grid_model_dt_rougher.fit(features_for_train, target_for_rougher_train)

params_dtr_rougher = grid_model_dt_rougher.best_params_

decision_tree_regr_rougher = DecisionTreeRegressor(**params_dtr_rougher, random_state = state)
decision_tree_regr_rougher.fit(features_for_train, target_for_rougher_train)

print('Параметры модели: ', grid_model_dt_rougher.best_params_)
# Out:
# Параметры модели:  {'max_depth': 13}
# CPU times: user 26.7 s, sys: 119 ms, total: 26.8 s
# Wall time: 26.8 s

# %%
# %%time
# Gridsearch for final
grid_model_dt_final = GridSearchCV(DecisionTreeRegressor(random_state=state), 
                                             param_grid = params_dtr_grid, 
                                             cv=KFold(5, shuffle=True, random_state=state),
                                             n_jobs=-1,
                                             scoring=smape_score) 

grid_model_dt_final.fit(features_for_train, target_for_final_train)

params_dtr_final = grid_model_dt_final.best_params_

decision_tree_regr_final = DecisionTreeRegressor(**params_dtr_final, random_state = state)
decision_tree_regr_final.fit(features_for_train, target_for_final_train)

print('Параметры модели: ', params_dtr_final)
# Out:
# Параметры модели:  {'max_depth': 12}
# CPU times: user 28.6 s, sys: 83.4 ms, total: 28.7 s
# Wall time: 28.7 s

# %%
grid_dt_result_smape = final_sMAPE(grid_model_dt_rougher.best_score_, grid_model_dt_final.best_score_)*(-1)
scores['DecisionTreeRegressor_grid'] = [grid_dt_result_smape]

# %% [markdown]
# ### Модель RandomForestRegressor

# %%
# %%time
#GridSearchCV for rougher
param_rf_grid = {
    'n_estimators' : range(10, 100, 10),
    'max_depth' : range(1, 10)
}

grid_rf_rougher = GridSearchCV(RandomForestRegressor(random_state=state),
                               param_grid = param_rf_grid, 
                               cv=KFold(5, shuffle=True, random_state=state), 
                               n_jobs=-1, 
                               scoring=smape_score) 

grid_rf_rougher.fit(features_for_train, target_for_rougher_train)

params_rf_rougher = grid_rf_rougher.best_params_

random_forest_regr_rougher = RandomForestRegressor(**params_rf_rougher, random_state = state)
random_forest_regr_rougher.fit(features_for_train, target_for_rougher_train)

print('Параметры модели: ', params_rf_rougher)
# Out:
# Параметры модели:  {'max_depth': 9, 'n_estimators': 70}
# CPU times: user 59min 51s, sys: 10.5 s, total: 1h 1s
# Wall time: 1h 7s

# %%
# %%time
# Gridsearch for final
grid_rf_final = GridSearchCV(RandomForestRegressor(random_state=state), 
                             param_grid = param_rf_grid, 
                             cv=KFold(5, shuffle=True, random_state=state), 
                             n_jobs=-1, 
                             scoring=smape_score) 

grid_rf_final.fit(features_for_train, target_for_final_train)

params_rf_final = grid_rf_final.best_params_

random_forest_regr_final = RandomForestRegressor(**params_rf_final, random_state = state)
random_forest_regr_final.fit(features_for_train, target_for_final_train)

print('Параметры модели: ', params_rf_final)
# Out:
# Параметры модели:  {'max_depth': 9, 'n_estimators': 90}
# CPU times: user 1h 57s, sys: 11.6 s, total: 1h 1min 9s
# Wall time: 1h 24min

# %%
grid_rf_result_smape = final_sMAPE(grid_rf_rougher.best_score_, grid_rf_final.best_score_)*(-1)
scores['RandomForestRegressor_grid'] = [grid_rf_result_smape]

# %%
scores = pd.DataFrame(data=scores)
scores
# Out:
#    LinearRegression  DecisionTreeRegressor_grid  RandomForestRegressor_grid
# 0          9.627829                    6.187824                    5.536318

# %% [markdown]
# Лучшая модель - RandomForestRegressor обученная GridSearchCV

# %% [markdown]
# ### Подготовим данные для тестирования и применим модель на тестовой выборке

# %% [markdown]
# Данные для тестирования

# %%
features_for_test = df_test.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_for_rougher_test = df_test['rougher.output.recovery']
target_for_final_test = df_test['final.output.recovery']

# %%
print(f'Параметры лучшей модели: \n\
- для этапа флотации {params_rf_rougher} \n\
- для финальной очистки {params_rf_final}')
# Out:
# Параметры лучшей модели:
# - для этапа флотации {'max_depth': 9, 'n_estimators': 70}
# - для финальной очистки {'max_depth': 9, 'n_estimators': 90}

# %%
model_for_test_rougher = RandomForestRegressor(n_estimators=70, max_depth=9, random_state=state)
model_for_test_rougher.fit(features_for_train, target_for_rougher_train)
predicted_rougher = model_for_test_rougher.predict(features_for_test)

model_for_test_final = RandomForestRegressor(n_estimators=90, max_depth=9, random_state=state)
model_for_test_final.fit(features_for_train, target_for_final_train)
predicted_final = model_for_test_final.predict(features_for_test)

smape_for_test_rougher = sMAPE(target_for_rougher_test, predicted_rougher)
smape_for_test_final = sMAPE(target_for_final_test, predicted_final)
final_smape_for_test = final_sMAPE(smape_for_test_rougher, smape_for_test_final)

# %%
print(f'sMAPE для тестовой выборки составляет - {final_smape_for_test}')
# Out:
# sMAPE для тестовой выборки составляет - 9.126727758960701

# %% [markdown]
# #### Проверка модели на адекватность

# %% [markdown]
# Вычислим показатель sMape для константной модели и сравним с результатами лучшей модели.

# %%
dummy_regr_for_rougher = DummyRegressor()
dummy_regr_for_final = DummyRegressor()

dummy_regr_for_rougher.fit(features_for_train, target_for_rougher_train) 
dummy_regr_for_final.fit(features_for_train, target_for_final_train)

dummy_predicted_rougher = dummy_regr_for_rougher.predict(features_for_test)
dummy_predicted_final = dummy_regr_for_final.predict(features_for_test)

smape_for_dummy_rougher = sMAPE(target_for_rougher_test, dummy_predicted_rougher)
smape_for_dummy_final = sMAPE(target_for_final_test, dummy_predicted_final)

final_smape_for_const = final_sMAPE(smape_for_dummy_rougher, smape_for_dummy_final)

# %%
print(f'sMAPE для константной модели - {final_smape_for_const}')
# Out:
# sMAPE для константной модели - 9.659123121738936

# %% [markdown]
# Показатель модели RandomForestRegressor меньше показателя константной.

# %% [markdown]
# ## **Вывод по проекту**
#
# - Пропуски в тренировочном и тестовом датасетах были заполнены значениями предшествующими по времени, нулевые значения для целевых признаков заменены на средние.
# - Проверена правильность расчета эффективности обогащения.
# - В тестовую выборку добавлены целевые признаки rougher.output.recovery и final.output.recovery.
# - Дубликаты в датасэтах не найдены не найдены, пропуски в значениях заполнены функцией ffill.
# - Доля золота на после каждого этапа очитски увеличивается.
# - Доля серебра увеличивается на этапе флотации, а затем постепенно снижается.
# - Доля свинца увеличивается на этапе флотации и после первичной очитски, но затем остатется примерно на одном уровне.
# - В данных для каждого металла присутствуют аномалии.
# - По распределениям видно, что в данных присутствуют выбросы и длинные левые хвосты.
# - Суммарная концентрация веществ увеличивается к финальному этапу, а диапазон распределения уменьшается.
# - Построено 6 моделей LinearRegression, DecisionTreeRegressor и RandomForestRegressor, по две на каждый целевой признак.
# - Моделью с лучшими результатами прогноза является - **RandomForestRegressor**
# - Лучшее значение 'sMAPE' на тренировочной выборке составил **5,53**, значение на тестовой выборке **9,12**.
# - Параметрами модели:
#     - для этапа флотации {'max_depth': 9, 'n_estimators': 70}
#     - для финальной очистки {'max_depth': 9, 'n_estimators': 90}
#
# - Модель проверена на адекватность, показатель sMAPE константной модели ниже значения для модели RandomForestRegressor.
